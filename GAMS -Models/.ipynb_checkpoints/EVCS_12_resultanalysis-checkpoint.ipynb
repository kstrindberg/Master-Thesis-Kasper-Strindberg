# %%
# in this model i have implemented 4% loss in the battery system
# Also i have tried to introduce a power flow hierarchy using BIG M

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import glob

# %%
all_files = glob.glob('EVCS_12_results.db')
print(all_files)

storage = pd.DataFrame()

for filename in glob.glob('EVCS_12_results.db'):
    con = sqlite3.connect(filename)
    grid_power = pd.read_sql_query("SELECT * FROM var_grid_power", con)
    grid_energy = pd.read_sql_query("SELECT * FROM var_grid_energy", con)
    ESS_level = pd.read_sql_query('SELECT * FROM var_ESS_level', con)
    charging = pd.read_sql_query('SELECT * FROM var_grid2ess_power', con)
    discharging = pd.read_sql_query('SELECT * FROM var_ess2load_power', con)
    grid2load = pd.read_sql_query('SELECT * FROM var_grid2load_power', con)
    
    
    con.close()

# %%
plt.plot(ESS_level['level'])

# %%
soc = ESS_level['level']

# %%
min(soc)
# Out:
# 23.416808743169412

# %%
batout = discharging['level']

# %%
plt.plot(batout)

# %%
grid = grid_power['level']

# %%
plt.plot(grid)

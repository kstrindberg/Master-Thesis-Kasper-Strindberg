# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import glob

# %%
all_files = glob.glob('EVCS_3_results.db')

storage = pd.DataFrame()

for filename in glob.glob('EVCS_3_results.db'):
    con = sqlite3.connect(filename)
    grid_power = pd.read_sql_query("SELECT * FROM var_grid_power", con)
    el_cost = pd.read_sql_query("SELECT * FROM var_electricity_cost", con)
    ESS_size = pd.read_sql_query('SELECT * FROM var_ESS_size', con)
    ESS_level = pd.read_sql_query('SELECT * FROM var_ESS_level', con)
    charging = pd.read_sql_query('SELECT * FROM var_charge', con)
    discharging = pd.read_sql_query('SELECT * FROM var_discharge', con)
    grid2load = pd.read_sql_query('SELECT * FROM var_grid2load', con)
    
    con.close()
    #storage[filename[21:-3]] = installed_storage['level'].copy()
    #df[filename] = installed_capacity['level'].copy()

# %%
demand = pd.read_csv('demand_7-14_feb.tsv', sep = ' ', header = None)
demand = demand.rename(columns = {1 : 'level'})

# %%
plt.plot(grid_power['level'])

# %%
plt.plot(charging['level'])

# %%
plt.plot(discharging['level'])
plt.plot(demand['level'])

# %%
plt.plot(ESS_level['level'])

# %%
plt.plot(grid2load['level'])

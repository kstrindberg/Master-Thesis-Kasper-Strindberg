# %%
# In this file i have originally run similar model to EVSC_8. I will  look into Voltage and Current over the battery

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import glob

# %%
all_files = glob.glob('EVCS_9_results.db')

storage = pd.DataFrame()

for filename in glob.glob('EVCS_9_results.db'):
    con = sqlite3.connect(filename)
    grid_power = pd.read_sql_query("SELECT * FROM var_grid_power_lo", con)
    grid_energy = pd.read_sql_query("SELECT * FROM var_grid_energy", con)
    ESS_level = pd.read_sql_query('SELECT * FROM var_ESS_level', con)
    charging = pd.read_sql_query('SELECT * FROM var_grid2ess_power', con)
    discharging = pd.read_sql_query('SELECT * FROM var_ess2load_power', con)
    grid2load = pd.read_sql_query('SELECT * FROM var_grid2load_power', con)
    
    
    con.close()

# %%
dis = discharging['level'].tolist()
volt = []
current = 94

# %%
for i in range(len(dis)):
    volt.append((1000*dis[i])/current)

# %%
plt.plot(volt)

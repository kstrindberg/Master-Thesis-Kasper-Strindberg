# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import glob

# %%
all_files = glob.glob('EVCS_11_results.db')

storage = pd.DataFrame()

for filename in glob.glob('EVCS_11_results.db'):
    con = sqlite3.connect(filename)
    grid_power = pd.read_sql_query("SELECT * FROM var_grid_power", con)
    grid_energy = pd.read_sql_query("SELECT * FROM var_grid_energy", con)
    ESS_level = pd.read_sql_query('SELECT * FROM var_ESS_level', con)
    charging = pd.read_sql_query('SELECT * FROM var_grid2ess_power', con)
    discharging = pd.read_sql_query('SELECT * FROM var_ess2load_power', con)
    grid2load = pd.read_sql_query('SELECT * FROM var_grid2load_power', con)
    
    
    con.close()

# %%
plt.plot(ESS_level['level'])

# %%
ESS = ESS_level['level']
gridpower = grid_power['level']
grid2load = grid2load['level']
grid2ess = charging['level']
ess2load = discharging['level']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-c4384e467ba5> in <module>
#       1 ESS = ESS_level['level']
#       2 gridpower = grid_power['level']
# ----> 3 grid2load = grid2load['level']
#       4 grid2ess = charging['level']
#       5 ess2load = discharging['level']
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# ...

# %%
#plt.plot(ESS.iloc[0:200], label = 'ESS Level')
#plt.plot(gridpower.iloc[0:200], label = 'grid power')
#plt.plot(grid2ess.iloc[0:200], label = 'grid2ess')
plt.plot(ess2load.iloc[100:200], label = 'ess2load')
plt.plot(grid2load.iloc[100:200],label = 'grid2load')
plt.legend()

# %%
plt.plot(ESS.iloc[1000:2900])

# %%
min(ESS)
# Out:
# 22.50090909090908

# %%
max(gridpower)
# Out:
# 277.60931818181825

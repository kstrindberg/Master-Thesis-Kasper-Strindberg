# %%
import pandas as pd
import numpy as np

# %%
time = np.arange(0,2016,1)
ind = []

for i in range(len(time)):
    ind.append('m' + str(time[i]) + '.grid2ess')
    
    
#ind=np.array(ind)

# %%
ind
# Out:
# ['m0.grid2ess',
#  'm1.grid2ess',
#  'm2.grid2ess',
#  'm3.grid2ess',
#  'm4.grid2ess',
#  'm5.grid2ess',
#  'm6.grid2ess',
#  'm7.grid2ess',
#  'm8.grid2ess',
#  'm9.grid2ess',
#  'm10.grid2ess',
#  'm11.grid2ess',
#  'm12.grid2ess',
#  'm13.grid2ess',
#  'm14.grid2ess',
#  'm15.grid2ess',
#  'm16.grid2ess',
#  'm17.grid2ess',
#  'm18.grid2ess',
#  'm19.grid2ess',
#  'm20.grid2ess',
#  'm21.grid2ess',
#  'm22.grid2ess',
#  'm23.grid2ess',
#  'm24.grid2ess',
#  'm25.grid2ess',
#  'm26.grid2ess',
#  'm27.grid2ess',
#  'm28.grid2ess',
#  'm29.grid2ess',
#  'm30.grid2ess',
#  'm31.grid2ess',
#  'm32.grid2ess',
#  'm33.grid2ess',
#  'm34.grid2ess',
#  'm35.grid2ess',
#  'm36.grid2ess',
#  'm37.grid2ess',
#  'm38.grid2ess',
#  'm39.grid2ess',
#  'm40.grid2ess',
#  'm41.grid2ess',
#  'm42.grid2ess',
#  'm43.grid2ess',
#  'm44.grid2ess',
#  'm45.grid2ess',
#  'm46.grid2ess',
#  'm47.grid2ess',
#  'm48.grid2ess',
#  'm49.grid2ess',
#  'm50.grid2ess',
#  'm51.grid2ess',
#  'm52.grid2ess',
# ...

# %%
time = np.arange(0,2016,1)
ind2 = []

for i in range(len(time)):
    ind2.append('m' + str(time[i]) + '.grid2load')
    
    
#ind2=np.array(ind2)

# %%
ind2
# Out:
# ['m0.grid2load',
#  'm1.grid2load',
#  'm2.grid2load',
#  'm3.grid2load',
#  'm4.grid2load',
#  'm5.grid2load',
#  'm6.grid2load',
#  'm7.grid2load',
#  'm8.grid2load',
#  'm9.grid2load',
#  'm10.grid2load',
#  'm11.grid2load',
#  'm12.grid2load',
#  'm13.grid2load',
#  'm14.grid2load',
#  'm15.grid2load',
#  'm16.grid2load',
#  'm17.grid2load',
#  'm18.grid2load',
#  'm19.grid2load',
#  'm20.grid2load',
#  'm21.grid2load',
#  'm22.grid2load',
#  'm23.grid2load',
#  'm24.grid2load',
#  'm25.grid2load',
#  'm26.grid2load',
#  'm27.grid2load',
#  'm28.grid2load',
#  'm29.grid2load',
#  'm30.grid2load',
#  'm31.grid2load',
#  'm32.grid2load',
#  'm33.grid2load',
#  'm34.grid2load',
#  'm35.grid2load',
#  'm36.grid2load',
#  'm37.grid2load',
#  'm38.grid2load',
#  'm39.grid2load',
#  'm40.grid2load',
#  'm41.grid2load',
#  'm42.grid2load',
#  'm43.grid2load',
#  'm44.grid2load',
#  'm45.grid2load',
#  'm46.grid2load',
#  'm47.grid2load',
#  'm48.grid2load',
#  'm49.grid2load',
# ...

# %%
CF = np.ones(4032, dtype=int)

# %%
ind3 = ind+ind2
ind3 = (np.array(ind3))

# %%
CF_grid = pd.DataFrame(CF, index=ind3)

# %%
display(CF_grid)
# Out:
#                  0
# m0.grid2ess      1
# m1.grid2ess      1
# m2.grid2ess      1
# m3.grid2ess      1
# m4.grid2ess      1
# ...             ..
# m2011.grid2load  1
# m2012.grid2load  1
# m2013.grid2load  1
# m2014.grid2load  1
# m2015.grid2load  1
#
# [4032 rows x 1 columns]

# %%
#CF_grid.to_csv('CF_grid', sep = ',')
